# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %% [markdown]
# ## Paso 1. Importar librerias necesarias

# %%
import pandas as pd

# %% [markdown]
# ## Paso 2. Estos son los datos dados como diccionario

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ## Paso 3. Crea un marco de datos y asígnalo a una variable llamada ejército.
#
# ##### No olvide incluir los nombres de las columnas en el orden presentado en el diccionario ('regimiento', 'compañía', 'muertes'...) para que el orden del índice de columnas sea coherente con las soluciones. Si se omite, pandas ordenará las columnas alfabéticamente.

# %%
army=pd.DataFrame(raw_data)

# %% [markdown]
# ## Paso 4. Establezca la columna "origen" como índice del marco de datos

# %%
army=army.set_index('origin')
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ## Paso 5. Imprima sólo los veteranos de columna

# %%
print(army.veterans)
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %% [markdown]
# ## Paso 6. Imprimir las columnas "veteranos" y "fallecidos

# %%
print(army[['veterans','deaths']])
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %% [markdown]
# ## Paso 7. Imprime el nombre de todas las columnas.

# %%
print(list(army.columns))
# Out:
# ['regiment', 'company', 'deaths', 'battles', 'size', 'veterans', 'readiness', 'armored', 'deserters']

# %% [markdown]
# ## Paso 8. Seleccionar las columnas "muertos", "tamaño" y "desertores" de Maine y Alaska.

# %%
army.loc[['Maine','Alaska'], ['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ## Paso 9. Seleccione las filas 3 a 7 y las columnas 3 a 6

# %%
army.iloc[2:7,2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %% [markdown]
# ## Paso 10. Seleccione todas las filas después de la cuarta fila y todas las columnas

# %%
army.iloc[3:,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ## Paso 11. Seleccione todas las filas hasta la 4ª fila y todas las columnas

# %%
army.iloc[:4,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %% [markdown]
# ## Paso 12. Seleccione la 3ª columna hasta la 7ª columna

# %%
army.iloc[:,2:7]
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Arizona        523        5  1045         1          1
# California      52       42   957         5          2
# Texas           25        2  1099        62          3
# Florida        616        2  1400        26          3
# Maine           43        4  1592        73          2
# Iowa           234        7  1006        37          1
# Alaska         523        8   987       949          2
# Washington      62        3   849        48          3
# Oregon          62        4   973        48          2
# Wyoming         73        7  1005       435          1
# Louisana        37        8  1099        63          2
# Georgia         35        9  1523       345          3

# %% [markdown]
# ## Paso 13. Seleccione las filas en las que df.deaths es mayor que 50

# %%
army.query('deaths>50')
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3

# %% [markdown]
# ## Paso 14. Seleccione las filas en las que df.deaths es mayor que 500 o menor que 50

# %%
army.query('regiment>50 and deaths<500')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\Data_Analysis\2-Pandas\Practica\4-Fictional_Army\Fictional Army.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/0205301/OneDrive%20-%20SENER/Documentos/GitHub/DS_PT_09_2023/Data_Analysis/2-Pandas/Practica/4-Fictional_Army/Fictional%20Army.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> army.query('regiment>50 and deaths<500')
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\frame.py:4602, in DataFrame.query(self, expr, inplace, **kwargs)
#    4600 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4601 kwargs["target"] = None
# -> 4602 res = self.eval(expr, **kwargs)
#    4604 try:
#    4605     result = self.loc[res]
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\frame.py:4728, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4725     kwargs["target"] = self
#    4726 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4728 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:808, in Expr.__init__(self, expr, engine, parser, env, level)
#     806 self.parser = parser
#     807 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 808 self.terms = self.parse()
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:827, in Expr.parse(self)
#     823 def parse(self):
#     824     """
#     825     Parse an expression.
#     826     """
# --> 827     return self._visitor.visit(self.expr)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:745, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     742     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     744 operands = node.values
# --> 745 return reduce(visitor, operands)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:738, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     737 def visitor(x, y):
# --> 738     lhs = self._try_visit_binop(x)
#     739     rhs = self._try_visit_binop(y)
#     741     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:734, in BaseExprVisitor._try_visit_binop(self, bop)
#     732 if isinstance(bop, (Op, Term)):
#     733     return bop
# --> 734 return self.visit(bop)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:718, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     716     op = self.translate_In(ops[0])
#     717     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 718     return self.visit(binop)
#     720 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     721 left = node.left
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:533, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     532 left, right = self._maybe_downcast_constants(left, right)
# --> 533 return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:527, in BaseExprVisitor._maybe_evaluate_binop(self, op, op_class, lhs, rhs, eval_in_python, maybe_eval_in_python)
#     520 elif self.engine != "pytables":
#     521     if (
#     522         getattr(lhs, "return_type", None) == object
#     523         or getattr(rhs, "return_type", None) == object
#     524     ):
#     525         # evaluate "==" and "!=" in python if either of our operands
#     526         # has an object return type
# --> 527         return self._maybe_eval(res, eval_in_python + maybe_eval_in_python)
#     528 return res
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\expr.py:487, in BaseExprVisitor._maybe_eval(self, binop, eval_in_python)
#     480 def _maybe_eval(self, binop, eval_in_python):
#     481     # eval `in` and `not in` (for now) in "partial" python space
#     482     # things that can be evaluated in "eval" space will be turned into
#    (...)
#     485     # in that case a + 2 * b will be evaluated using numexpr, and the "in"
#     486     # call will be evaluated using isin (in python space)
# --> 487     return binop.evaluate(
#     488         self.env, self.engine, self.parser, self.term_type, eval_in_python
#     489     )
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\ops.py:430, in BinOp.evaluate(self, env, engine, parser, term_type, eval_in_python)
#     413 """
#     414 Evaluate a binary operation *before* being passed to the engine.
#     415
#    (...)
#     427     The "pre-evaluated" expression as an instance of ``term_type``
#     428 """
#     429 if engine == "python":
# --> 430     res = self(env)
#     431 else:
#     432     # recurse over the left/right nodes
#     434     left = self.lhs.evaluate(
#     435         env,
#     436         engine=engine,
#    (...)
#     439         eval_in_python=eval_in_python,
#     440     )
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\computation\ops.py:410, in BinOp.__call__(self, env)
#     407 left = self.lhs(env)
#     408 right = self.rhs(env)
# --> 410 return self.func(left, right)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\ops\array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\0205301\OneDrive - SENER\Documentos\GitHub\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\ops\array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ## Paso 15. Seleccione todos los regimientos que no se llamen "Dragones".

# %%
army.query('regiment !="Dragoons"')
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ## Paso 16. Seleccione las filas denominadas Texas y Arizona

# %%
army.loc[['Texas','Arizona']]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %% [markdown]
# ## Paso 17. Seleccione la tercera celda de la fila llamada Arizona

# %%
army.loc['Arizona'].iloc[2]

# %% [markdown]
# ## Paso 18. Seleccione la tercera celda de la columna denominada muertes

# %%
army.iloc[4]['deaths']
# Out:
# 43

# %% [markdown]
# ## Paso 19. Guarde el dataframe en un csv

# %%
army.to_csv('army.csv')
