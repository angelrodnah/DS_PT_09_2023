# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
# Análisis Exploratorio de Datos Específico de Usuarios Motoristas de una Administración Publica de Carreteras

# %% [markdown]
# ### TEMA

# %% [markdown]
# # El Servicio de Seguridad Vial de una Determinada Administración, por los registros de accidentes producidos en carreteras que le llegan de la Dirección General de Tráfico, se teme que uno de los tipos de usuarios que están más en riesgo son lo usuarios motoristas. Por este motivo se encarga realizar un Análisis exploratorio de la base de datos  para comprender las tendencias y patrones asociados con este grupo específico de personas.

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Puede que tengas más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# # Los usuarios motoristas son el principal grupo de riesgo en lesividad, esto es, que cuando se produce un accidente es el grupo que más lesividad acumula y el que tiene más tendencia a que si no se realizan actuaciones correctoras en este grupo se agravará la situación.

# %% [markdown]
# **Hipótesis adicionales:**
# 1. **Condiciones de ubicación**:
#    - Los accidentes de motoristas son más comunes en áreas periurbanas, especialmente en curvas y carreteras con poco tráfico.
#    - La mayoría de los accidentes de motoristas ocurren en áreas de baja velocidad de circulación.
# 2. **Impacto de factores externos**:
#    - Los accidentes de motoristas tienden a aumentar en días de lluvia.
#    - Los accidentes de motoristas son más frecuentes con menor visibilidad.
# 3. **Impacto de factores internos**:
#    - El exceso de velocidad es un factor significativo en accidentes de motoristas severos.
#    - La conducción por ocio contribuye a una proporción significativa de los accidentes de motoristas.
# 4. **Lesiones y consecuencias**:
#    - La tipología de accidente es principalmente por salida de vía.
#    - Los accidentes de motoristas tienden a resultar en lesiones graves, como fracturas y traumatismos craneales.
# 5. **Patrones de motoristas**:
#    - Los accidentes de motoristas tienden a resultar en lesiones graves, como fracturas y traumatismos craneales.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# La Dirección General de Tráfico proporciona una Base de Datos de Accidentes (bbdd) registrados en las Carreteras que son administradas por la Autoridad competente( la Administración). Esta Base de datos está estructurada en tres tablas codificadas: Accidentes, Personas y Vehículos.
# Se decodifican a través de tablas auxiliares y se relacionan mediante un Id, por lo que se puede tener una tabla única para poder realizar el Análisis.
# Dado el caracter confidencial de los datos se han enmascarado ciertos campos para anonimizar los datos.

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import pandas as pd

# %%
pd.read_csv('Accidentes_Bridge.csv')
# Out:
#    Unnamed: 0 CodTipoAcci CodSubTipoAcc  IDAcc           RefC  CODICAR  \
# 0           0     SVC_B_I            SV     12  142A050001141    BI-30
# 1           1        OC_X           XXX     24  553A050000353   BI-631
# 2           2     CO_Barr           CHQ  68911          45587    BI-20
# 3           3          CL            CL  68914          61892   BI-625
# 4           4        OC_X           XXX  68918          18718  BI-3742
#
#    CODRAMAL      KM      KM2  SENTIDO  ... dvVISlegal           ACV   IG  \
# 0       NaN    8200    80200        2  ...        NaN  Con Víctimas  0.0
# 1       NaN   19800   190800        2  ...        NaN  Con Víctimas  0.0
# 2       NaN    7100    70090        2  ...        NaN  Con Víctimas  0.0
# 3       NaN  391500  3910550        1  ...        NaN  Con Víctimas  0.0
# 4       NaN    7500    70570        1  ...        NaN  Con Víctimas  0.0
#
#    CosteAcc    HORA0   HORA05   HORA10   HORA15   HORA30              Sec
# ...

# %%
pd.read_csv('Personas_Bridge.csv')
# Out:
#    Unnamed: 0  IdAcc        RefCper       txtdef_fis_prev  txtlocLes  \
# 0           0   12.0  142A050001141  Sin defecto conocido      Pecho
# 1           1   24.0  553A050000353  Sin defecto conocido  Sin datos
# 2           2   24.0  553A050000353  Sin defecto conocido     Cuello
# 3           3   13.0  142A050001242  Sin defecto conocido  Sin datos
# 4           4   13.0  142A050001242  Sin defecto conocido  Sin datos
#
#              txtkitSeg   txthcondc                txtPsi  \
# 0  Utilizando cinturón  Menos de 1  Aparentemente normal
# 1  Utilizando cinturón  Menos de 1  Aparentemente normal
# 2  Utilizando cinturón  Menos de 1  Aparentemente normal
# 3  Utilizando cinturón  Menos de 1  Aparentemente normal
# 4  Utilizando cinturón  Menos de 1  Aparentemente normal
#
#                   txtaccion_cond txtinfrvel  ...  \
# 0                 Siguiendo ruta  Se ignora  ...
# 1                 Siguiendo ruta  Se ignora  ...
# 2                 Siguiendo ruta  Se ignora  ...
# ...

# %%
pd.read_csv('Vehiculos_Bridge.csv')
# Out:
#    Unnamed: 0  IdAcc  nCor   Referencia  IdVeh  ordVeh        RefCveh  \
# 0           0   12.0  41.0  142A0500011   3888     1.0  142A050001141
# 1           1   13.0  42.0  142A0500012   3889     1.0  142A050001242
# 2           2   13.0  42.0  142A0500012   3890     2.0  142A050001242
# 3           3   13.0  42.0  142A0500012   3891     3.0  142A050001242
# 4           4   13.0  42.0  142A0500012   3892     4.0  142A050001242
#
#                       txtEstado      txtMP               txttxtDesp  ...  \
# 0  Aparentemente ningún defecto  Sin datos  Local (menos de 50 km.)  ...
# 1  Aparentemente ningún defecto  Sin datos  Local (menos de 50 km.)  ...
# 2  Aparentemente ningún defecto  Sin datos  Local (menos de 50 km.)  ...
# 3  Aparentemente ningún defecto  Sin datos  Local (menos de 50 km.)  ...
# 4  Aparentemente ningún defecto  Sin datos  Local (menos de 50 km.)  ...
#
#                         txtModelo CodTipoAcci CodSubTipoAcc tipoTrav  \
# ...
